# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# bike trip files
march_path = "resources/citibike_march_2019.csv"
april_path = "resources/citibike_april_2019.csv"
may_path = "resources/citibike_may_2019.csv"
june_path = "resources/citibike_june_2019.csv"

# Read the csv files
marchData = pd.read_csv(march_path)
aprilData = pd.read_csv(april_path)
mayData = pd.read_csv(may_path)
juneData = pd.read_csv(june_path)

# output variable
marchapril_file = "~/desktop/creativity/data_analytics/git/bike_sharing_program/resources/marchapril.csv"
mayjune_file = "~/desktop/creativity/data_analytics/git/bike_sharing_program/resources/mayjune.csv"
complete_file = "~/desktop/creativity/data_analytics/git/bike_sharing_program/data/bike_share_data.csv"


# Combine march and april into a single dataset
marchAprilData = pd.merge(marchData, aprilData, how="right")

# Display the data table for preview
marchAprilData.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
# Create dataframe
marchAprilData_df = pd.DataFrame(marchAprilData)
marchAprilData_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1               493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2               512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3               196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4               463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
# ...             ...                       ...                       ...
# 33051           335  2019-04-27 20:12:13.3830  2019-04-27 20:17:48.5690
# 33052           679  2019-04-28 13:23:04.7290  2019-04-28 13:34:23.7550
# 33053           793  2019-04-29 13:46:39.2540  2019-04-29 13:59:52.2890
# 33054           706  2019-04-30 10:47:41.6730  2019-04-30 10:59:28.5910
# 33055           721  2019-04-30 19:30:56.2830  2019-04-30 19:42:57.6050
#
#        start station id start station name  start station latitude  \
# ...

# %%
marchAprilData_df.count()
# Out:
# tripduration               33056
# starttime                  33056
# stoptime                   33056
# start station id           33056
# start station name         33056
# start station latitude     33056
# start station longitude    33056
# end station id             33056
# end station name           33056
# end station latitude       33056
# end station longitude      33056
# bikeid                     33056
# usertype                   33056
# birth year                 33056
# gender                     33056
# dtype: int64

# %%
# Output marchapril file
marchAprilData_df.to_csv(marchapril_file)
marchAprilData_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1               493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2               512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3               196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4               463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
# ...             ...                       ...                       ...
# 33051           335  2019-04-27 20:12:13.3830  2019-04-27 20:17:48.5690
# 33052           679  2019-04-28 13:23:04.7290  2019-04-28 13:34:23.7550
# 33053           793  2019-04-29 13:46:39.2540  2019-04-29 13:59:52.2890
# 33054           706  2019-04-30 10:47:41.6730  2019-04-30 10:59:28.5910
# 33055           721  2019-04-30 19:30:56.2830  2019-04-30 19:42:57.6050
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Create new dataframe
weatherData = {
    "City": name,
    "Country": country,
    "Latitude": lat,
    "Longitude": lon,
    "Temperature (F)": temp,
    "Humidity (%)": humid,
    "Windspeed (mph)": wind,
    "Cloudiness (%)": cloud,
}
weatherData_df=pd.DataFrame(weatherData)

# Creating CSV in designated folder, and display dataframe
weatherData_df.to_csv(output_data_file)
weatherData_df

# %%
# Combine may and june into a single dataset
mayJuneData = pd.merge(mayData, juneData, how="right")

# Display the data table for a preview
mayJuneData.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1           280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2          2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3          2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4           139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
#
#    start station id start station name  start station latitude  \
# 0              3187          Warren St               40.721124
# 1              3185          City Hall               40.717733
# 2              3199       Newport Pkwy               40.728745
# 3              3199       Newport Pkwy               40.728745
# 4              3207        Oakland Ave               40.737604
#
#    start station longitude  end station id end station name  \
# 0               -74.038051            3199     Newport Pkwy
# ...

# %%
# Create dataframe
mayJuneData_df = pd.DataFrame(mayJuneData)
mayJuneData_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1               280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2              2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3              2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4               139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
# ...             ...                       ...                       ...
# 39425           639  2019-06-30 23:38:29.5450  2019-06-30 23:49:09.2110
# 39426           643  2019-06-30 23:38:34.9100  2019-06-30 23:49:17.9690
# 39427           418  2019-06-30 23:42:30.9400  2019-06-30 23:49:29.5360
# 39428          2529  2019-06-30 23:46:17.5700  2019-07-01 00:28:27.1710
# 39429           831  2019-06-30 23:49:01.6830  2019-07-01 00:02:53.1150
#
#        start station id start station name  start station latitude  \
# ...

# %%
mayJuneData_df.count()
# Out:
# tripduration               39430
# starttime                  39430
# stoptime                   39430
# start station id           39430
# start station name         39430
# start station latitude     39430
# start station longitude    39430
# end station id             39430
# end station name           39430
# end station latitude       39430
# end station longitude      39430
# bikeid                     39430
# usertype                   39430
# birth year                 39430
# gender                     39430
# dtype: int64

# %%
# Output mayjune data file
mayJuneData_df.to_csv(mayjune_file)
mayJuneData_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1               280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2              2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3              2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4               139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
# ...             ...                       ...                       ...
# 39425           639  2019-06-30 23:38:29.5450  2019-06-30 23:49:09.2110
# 39426           643  2019-06-30 23:38:34.9100  2019-06-30 23:49:17.9690
# 39427           418  2019-06-30 23:42:30.9400  2019-06-30 23:49:29.5360
# 39428          2529  2019-06-30 23:46:17.5700  2019-07-01 00:28:27.1710
# 39429           831  2019-06-30 23:49:01.6830  2019-07-01 00:02:53.1150
#
#        start station id start station name  start station latitude  \
# ...

# %%
marchApril_path = "resources/marchapril.csv"
mayJune_path = "resources/mayjune.csv"

marchAprilFile = pd.read_csv(marchApril_path)
mayJuneFile = pd.read_csv(mayJune_path)

completeData = pd.merge(marchAprilFile, mayJuneFile, how="right")
completeData
# Out:
#        Unnamed: 0  tripduration                 starttime  \
# 0               0           316  2019-06-01 00:05:55.7210
# 1               1           280  2019-06-01 00:08:09.0920
# 2               2          2162  2019-06-01 00:13:11.8800
# 3               3          2184  2019-06-01 00:13:30.1110
# 4               4           139  2019-06-01 00:13:31.8520
# ...           ...           ...                       ...
# 39425       39425           639  2019-06-30 23:38:29.5450
# 39426       39426           643  2019-06-30 23:38:34.9100
# 39427       39427           418  2019-06-30 23:42:30.9400
# 39428       39428          2529  2019-06-30 23:46:17.5700
# 39429       39429           831  2019-06-30 23:49:01.6830
#
#                        stoptime  start station id start station name  \
# 0      2019-06-01 00:11:11.9940              3187          Warren St
# 1      2019-06-01 00:12:50.0730              3185          City Hall
# ...

# %%
# Combine all data
completeData_df = pd.merge(mayJuneData_df, marchAprilData_df, how="right")

# Display for preview
completeData_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
completeData_df.count()
# Out:
# tripduration               33056
# starttime                  33056
# stoptime                   33056
# start station id           33056
# start station name         33056
# start station latitude     33056
# start station longitude    33056
# end station id             33056
# end station name           33056
# end station latitude       33056
# end station longitude      33056
# bikeid                     33056
# usertype                   33056
# birth year                 33056
# gender                     33056
# dtype: int64
